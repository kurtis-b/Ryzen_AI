# %% [markdown]
# Need to import the npu package to be able to use the kernel magic.

# %%
import npu

# %% [markdown]
# ## Kernel Code
# The kernel will perform 64x64x64 int8 MACs. It will take at least 1024 cycles to compute.

# %%
# %%kernel
#
# void mmul(uint8_t * __restrict pA, uint8_t * __restrict pB, uint8_t * __restrict pC)
# {
#     const int M = 8;
#     const int K = 8;
#     const int N = 8;
#     const int rowA = 64 / M;
#     const int colA = 64 / K;
#     const int colB = 64 / N;
#     using MMUL = ::aie::mmul<M, K, N, uint8_t, uint8_t>;
#
#     for (unsigned z = 0; z < rowA; z += 2) chess_prepare_for_pipelining {
#         uint8_t * __restrict pC1 = pC + (      z * colB +       0) * MMUL::size_C;
#         uint8_t * __restrict pC2 = pC + ((z + 1) * colB +       0) * MMUL::size_C;
#         for (unsigned j = 0; j < colB; j += 2) chess_prepare_for_pipelining {
#             const uint8_t * __restrict pA1 = pA + (      z * colA +       0) * MMUL::size_A;
#             const uint8_t * __restrict pA2 = pA + ((z + 1) * colA +       0) * MMUL::size_A;
#             const uint8_t * __restrict pB1 = pB + (      0 * colB +       j) * MMUL::size_B;
#             const uint8_t * __restrict pB2 = pB + (      0 * colB + (j + 1)) * MMUL::size_B;
#             ::aie::vector<uint8_t, MMUL::size_A> A0 = ::aie::load_v<MMUL::size_A>(pA1);
#             pA1 += MMUL::size_A;
#             ::aie::vector<uint8_t, MMUL::size_A> A1 = ::aie::load_v<MMUL::size_A>(pA2);
#             pA2 += MMUL::size_A;
#             ::aie::vector<uint8_t, MMUL::size_B> B0 = ::aie::load_v<MMUL::size_B>(pB1);
#             pB1 += MMUL::size_B * colB;
#             ::aie::vector<uint8_t, MMUL::size_B> B1 = ::aie::load_v<MMUL::size_B>(pB2);
#             pB2 += MMUL::size_B * colB;
#
#             MMUL C00;
#             C00.mul(A0, B0);
#             MMUL C01;
#             C01.mul(A0, B1);
#             MMUL C10;
#             C10.mul(A1, B0);
#             MMUL C11;
#             C11.mul(A1, B1);
#
#             for (unsigned i = 1; i < colA; ++i) chess_prepare_for_pipelining {
#                 A0 = ::aie::load_v<MMUL::size_A>(pA1);
#                 pA1 += MMUL::size_A;
#                 A1 = ::aie::load_v<MMUL::size_A>(pA2);
#                 pA2 += MMUL::size_A;
#                 B0 = ::aie::load_v<MMUL::size_B>(pB1);
#                 pB1 += MMUL::size_B * colB;
#                 B1 = ::aie::load_v<MMUL::size_B>(pB2);
#                 pB2 += MMUL::size_B * colB;
#
#                 C00.mac(A0, B0);
#                 C01.mac(A0, B1);
#                 C10.mac(A1, B0);
#                 C11.mac(A1, B1);
#             }
#
#             ::aie::store_v(pC1, C00.template to_vector<uint8_t>());
#             pC1 += MMUL::size_C;
#             ::aie::store_v(pC1, C01.template to_vector<uint8_t>());
#             pC1 += MMUL::size_C;
#             ::aie::store_v(pC2, C10.template to_vector<uint8_t>());
#             pC2 += MMUL::size_C;
#             ::aie::store_v(pC2, C11.template to_vector<uint8_t>());
#             pC2 += MMUL::size_C;
#         }
#     }
# }

# %%
# Check the kernel has been created and is a Kernel type
mmul

# %%
# Check the kernel source code
print(mmul.srccode)
# Out:
# #define NOCPP
# #include <stdint.h>
# #include <stdio.h>
# #include <stdlib.h>
# #define REL_WRITE 0
# #define REL_READ 1
# #include <aie_api/aie.hpp>
#
#
#
# extern "C" {
# void mmul(uint8_t * __restrict pA, uint8_t * __restrict pB, uint8_t * __restrict pC)
# {
#     const int M = 8;
#     const int K = 8;
#     const int N = 8;
#     const int rowA = 64 / M;
#     const int colA = 64 / K;
#     const int colB = 64 / N;
#     using MMUL = ::aie::mmul<M, K, N, uint8_t, uint8_t>;
#
#     for (unsigned z = 0; z < rowA; z += 2) chess_prepare_for_pipelining {
#         uint8_t * __restrict pC1 = pC + (      z * colB +       0) * MMUL::size_C;
#         uint8_t * __restrict pC2 = pC + ((z + 1) * colB +       0) * MMUL::size_C;
#         for (unsigned j = 0; j < colB; j += 2) chess_prepare_for_pipelining {
#             const uint8_t * __restrict pA1 = pA + (      z * colA +       0) * MMUL::size_A;
#             const uint8_t * __restrict pA2 = pA + ((z + 1) * colA +       0) * MMUL::size_A;
#             const uint8_t * __restrict pB1 = pB + (      0 * colB +       j) * MMUL::size_B;
#             const uint8_t * __restrict pB2 = pB + (      0 * colB + (j + 1)) * MMUL::size_B;
#             ::aie::vector<uint8_t, MMUL::size_A> A0 = ::aie::load_v<MMUL::size_A>(pA1);
#             pA1 += MMUL::size_A;
#             ::aie::vector<uint8_t, MMUL::size_A> A1 = ::aie::load_v<MMUL::size_A>(pA2);
#             pA2 += MMUL::size_A;
#             ::aie::vector<uint8_t, MMUL::size_B> B0 = ::aie::load_v<MMUL::size_B>(pB1);
#             pB1 += MMUL::size_B * colB;
#             ::aie::vector<uint8_t, MMUL::size_B> B1 = ::aie::load_v<MMUL::size_B>(pB2);
#             pB2 += MMUL::size_B * colB;
#
#             MMUL C00;
#             C00.mul(A0, B0);
#             MMUL C01;
#             C01.mul(A0, B1);
#             MMUL C10;
#             C10.mul(A1, B0);
#             MMUL C11;
#             C11.mul(A1, B1);
#
#             for (unsigned i = 1; i < colA; ++i) chess_prepare_for_pipelining {
#                 A0 = ::aie::load_v<MMUL::size_A>(pA1);
#                 pA1 += MMUL::size_A;
#                 A1 = ::aie::load_v<MMUL::size_A>(pA2);
#                 pA2 += MMUL::size_A;
#                 B0 = ::aie::load_v<MMUL::size_B>(pB1);
#                 pB1 += MMUL::size_B * colB;
#                 B1 = ::aie::load_v<MMUL::size_B>(pB2);
#                 pB2 += MMUL::size_B * colB;
#
#                 C00.mac(A0, B0);
#                 C01.mac(A0, B1);
#                 C10.mac(A1, B0);
#                 C11.mac(A1, B1);
#             }
#
#             ::aie::store_v(pC1, C00.template to_vector<uint8_t>());
#             pC1 += MMUL::size_C;
#             ::aie::store_v(pC1, C01.template to_vector<uint8_t>());
#             pC1 += MMUL::size_C;
#             ::aie::store_v(pC2, C10.template to_vector<uint8_t>());
#             pC2 += MMUL::size_C;
#             ::aie::store_v(pC2, C11.template to_vector<uint8_t>());
#             pC2 += MMUL::size_C;
#         }
#     }
# }
# } // extern end

# %%
# Check the buffers that were created
mmul.metadata
# Out:
# {'name': 'mmul_0',
#  'tloc': None,
#  'ttype': 'CT',
#  'ktype': 'mmul',
#  'type': 'CT',
#  'ports': {'pA': {'c_dtype': None,
#    'direction': None,
#    'name': 'pA',
#    'ctype': None,
#    'shape': None,
#    'dtype': None},
#   'pB': {'c_dtype': None,
#    'direction': None,
#    'name': 'pB',
#    'ctype': None,
#    'shape': None,
#    'dtype': None},
#   'pC': {'c_dtype': None,
#    'direction': None,
#    'name': 'pC',
#    'ctype': None,
#    'shape': None,
#    'dtype': None}}}

# %% [markdown]
# ## NPU Graph
# Create a class for specifying the NPU graph.

# %%
import numpy as np

from npu.build.appbuilder import AppBuilder
from npu.build.kernel import Kernel
from npu.build.itkernel import ITWrite, ITRead


class Mmul(AppBuilder):

    def __init__(self, kernel: Kernel):
        self.kernel = kernel
        super().__init__()

    def callgraph(self, mtx_a: np.ndarray, mtx_b: np.ndarray, mtx_c: np.ndarray) -> None:
        input_a = ITRead(mtx_a)
        input_b = ITRead(mtx_b)
        kernel_output = self.kernel(input_a, input_b)
        _ = ITWrite(kernel_output, bufref=mtx_c)

# %%
import numpy as np

from npu.build.appbuilder import AppBuilder
from npu.build.kernel import Kernel

# Create an instance of the applicaiton
app_builder = Mmul(kernel=mmul)

# Trace the callgraph
mtx_a = np.zeros(shape=(64, 64), dtype=np.uint8)
mtx_b = np.zeros(shape=(64, 64), dtype=np.uint8)
mtx_c = np.zeros(shape=(64, 64), dtype=np.uint8)

# Define array size of pC to help the compiler determine the shape of the buffer
# Skipping this could cause a RuntimeError
app_builder.kernel.pC.array = np.ndarray(shape=(64, 64), dtype=np.uint8)
app_builder(mtx_a, mtx_b, mtx_c)

# %%
app_builder.display()

# %%
app_builder.build(mtx_a, mtx_b, mtx_c, debug=True, mlir="Mmul.mlir")
# Out:
# Using cached mmul kernel object file...
#
#
# Building the xclbin...
#
# RTNETLINK answers: File exists
# chess-clang: warning: argument unused during compilation: '-I /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib' [-Wunused-command-line-argument]
# chess-clang: warning: argument unused during compilation: '-I /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include' [-Wunused-command-line-argument]
# chess-clang: warning: argument unused during compilation: '-I /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/runtime_cxx/libs/libcxx-9.0.0/include-lite' [-Wunused-command-line-argument]
# chess-clang: warning: argument unused during compilation: '-I /opt/tools/Vitis/2023.1/aietools/data/aie_ml/lib/runtime/include' [-Wunused-command-line-argument]
# chess-clang: warning: argument unused during compilation: '-I <BOOST_DIR>' [-Wunused-command-line-argument]
# chess-clang: warning: argument unused during compilation: '-include aie_core.h' [-Wunused-command-line-argument]
# Found Vitis at /opt/tools/Vitis/2023.1
# created temporary directory aie.mlir.prj
# Running: builtin.module(lower-affine,aie-canonicalize-device,AIE.device(aie-assign-lock-ids,aie-register-objectFifos,aie-objectFifo-stateful-transform,aie-lower-broadcast-packet,aie-create-packet-flows,aie-lower-multicast,aie-assign-buffer-addresses),convert-scf-to-cf)
# aie-translate --aie-generate-corelist aie.mlir.prj/input_with_addresses.mlir
# aie-translate --aie-generate-target-arch aie.mlir.prj/input_with_addresses.mlir
# aie-opt --aie-img-to-dma --canonicalize --aie-dma-to-ipu aie.mlir.prj/input_with_addresses.mlir -o aie.mlir.prj/generated_ipu_insts.mlir
# Done in 0.098 sec: aie-opt --aie-img-to-dma --canonicalize --aie-dma-to-ipu aie.mlir.prj/input_with_addresses.mlir -o aie.mlir.prj/generated_ipu_insts.mlir
# aie-translate --aie-ipu-instgen aie.mlir.prj/generated_ipu_insts.mlir -o final.seq
# Done in 0.018 sec: aie-translate --aie-ipu-instgen aie.mlir.prj/generated_ipu_insts.mlir -o final.seq
# xchesscc_wrapper aie2 +w aie.mlir.prj/work -c -d -f +f +P 4 /opt/mlir-aie/aie_runtime_lib/AIE2/chess_intrinsic_wrapper.cpp -o aie.mlir.prj/chess_intrinsic_wrapper.ll
# Done in 5.140 sec: xchesscc_wrapper aie2 +w aie.mlir.prj/work -c -d -f +f +P 4 /opt/mlir-aie/aie_runtime_lib/AIE2/chess_intrinsic_wrapper.cpp -o aie.mlir.prj/chess_intrinsic_wrapper.ll
# sed -i s/^target.*// aie.mlir.prj/chess_intrinsic_wrapper.ll
# Done in 0.018 sec: sed -i s/^target.*// aie.mlir.prj/chess_intrinsic_wrapper.ll
# sed -i s/noalias_sidechannel[^,]*,// aie.mlir.prj/chess_intrinsic_wrapper.ll
# Done in 0.016 sec: sed -i s/noalias_sidechannel[^,]*,// aie.mlir.prj/chess_intrinsic_wrapper.ll
# sed -i s/nocallback[^,]*,// aie.mlir.prj/chess_intrinsic_wrapper.ll
# Done in 0.017 sec: sed -i s/nocallback[^,]*,// aie.mlir.prj/chess_intrinsic_wrapper.ll
# aie-opt --aie-localize-locks --aie-standard-lowering --aiex-standard-lowering --aie-normalize-address-spaces --canonicalize --cse --convert-vector-to-llvm --expand-strided-metadata --lower-affine --convert-math-to-llvm --convert-arith-to-llvm --convert-memref-to-llvm --convert-func-to-llvm=use-bare-ptr-memref-call-conv --convert-cf-to-llvm --canonicalize --cse aie.mlir.prj/input_with_addresses.mlir -o aie.mlir.prj/input_opt_with_addresses.mlir
# Done in 0.039 sec: aie-opt --aie-localize-locks --aie-standard-lowering --aiex-standard-lowering --aie-normalize-address-spaces --canonicalize --cse --convert-vector-to-llvm --expand-strided-metadata --lower-affine --convert-math-to-llvm --convert-arith-to-llvm --convert-memref-to-llvm --convert-func-to-llvm=use-bare-ptr-memref-call-conv --convert-cf-to-llvm --canonicalize --cse aie.mlir.prj/input_with_addresses.mlir -o aie.mlir.prj/input_opt_with_addresses.mlir
# aie-translate --opaque-pointers=0 --mlir-to-llvmir aie.mlir.prj/input_opt_with_addresses.mlir -o aie.mlir.prj/input.ll
# Done in 0.035 sec: aie-translate --opaque-pointers=0 --mlir-to-llvmir aie.mlir.prj/input_opt_with_addresses.mlir -o aie.mlir.prj/input.ll
# cp aie.mlir.prj/input.ll aie.mlir.prj/input.llchesshack.ll
# Done in 0.017 sec: cp aie.mlir.prj/input.ll aie.mlir.prj/input.llchesshack.ll
# sed -i s/noundef// aie.mlir.prj/input.llchesshack.ll
# Done in 0.016 sec: sed -i s/noundef// aie.mlir.prj/input.llchesshack.ll
# sed -i s/noalias_sidechannel[^,],// aie.mlir.prj/input.llchesshack.ll
# Done in 0.017 sec: sed -i s/noalias_sidechannel[^,],// aie.mlir.prj/input.llchesshack.ll
# llvm-link --opaque-pointers=0 aie.mlir.prj/input.llchesshack.ll aie.mlir.prj/chess_intrinsic_wrapper.ll -S -o aie.mlir.prj/input.llchesslinked.ll
# Done in 0.042 sec: llvm-link --opaque-pointers=0 aie.mlir.prj/input.llchesshack.ll aie.mlir.prj/chess_intrinsic_wrapper.ll -S -o aie.mlir.prj/input.llchesslinked.ll
# sed -i s/noundef// aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i s/noundef// aie.mlir.prj/input.llchesslinked.ll
# sed -i -E /define .*@/ s/%[0-9]*//g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E /define .*@/ s/%[0-9]*//g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/mustprogress//g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/mustprogress//g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/poison/undef/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/poison/undef/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/nocallback//g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.016 sec: sed -i -E s/nocallback//g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(none\)/readnone/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/memory\(none\)/readnone/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(read\)/readonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.018 sec: sed -i -E s/memory\(read\)/readonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(write\)/writeonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.016 sec: sed -i -E s/memory\(write\)/writeonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(argmem: readwrite\)/argmemonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/memory\(argmem: readwrite\)/argmemonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(argmem: read\)/argmemonly readonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/memory\(argmem: read\)/argmemonly readonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(argmem: write\)/argmemonly writeonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.016 sec: sed -i -E s/memory\(argmem: write\)/argmemonly writeonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(inaccessiblemem: readwrite\)/inaccessiblememonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/memory\(inaccessiblemem: readwrite\)/inaccessiblememonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(inaccessiblemem: read\)/inaccessiblememonly readonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.018 sec: sed -i -E s/memory\(inaccessiblemem: read\)/inaccessiblememonly readonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(inaccessiblemem: write\)/inaccessiblememonly writeonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.016 sec: sed -i -E s/memory\(inaccessiblemem: write\)/inaccessiblememonly writeonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(argmem: readwrite, inaccessiblemem: readwrite\)/inaccessiblemem_or_argmemonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.016 sec: sed -i -E s/memory\(argmem: readwrite, inaccessiblemem: readwrite\)/inaccessiblemem_or_argmemonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(argmem: read, inaccessiblemem: read\)/inaccessiblemem_or_argmemonly readonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.016 sec: sed -i -E s/memory\(argmem: read, inaccessiblemem: read\)/inaccessiblemem_or_argmemonly readonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/memory\(argmem: write, inaccessiblemem: write\)/inaccessiblemem_or_argmemonly writeonly/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/memory\(argmem: write, inaccessiblemem: write\)/inaccessiblemem_or_argmemonly writeonly/g aie.mlir.prj/input.llchesslinked.ll
# sed -i -E s/target triple = "aie.*"/target triple = "pdarch-unknown-unknown-elf"/g aie.mlir.prj/input.llchesslinked.ll
# Done in 0.017 sec: sed -i -E s/target triple = "aie.*"/target triple = "pdarch-unknown-unknown-elf"/g aie.mlir.prj/input.llchesslinked.ll
# xchesscc_wrapper aie2 +w aie.mlir.prj/work -c -d -f +P 4 aie.mlir.prj/input.llchesslinked.ll -o aie.mlir.prj/input.o
# Done in 12.125 sec: xchesscc_wrapper aie2 +w aie.mlir.prj/work -c -d -f +P 4 aie.mlir.prj/input.llchesslinked.ll -o aie.mlir.prj/input.o
# aie-opt --aie-create-pathfinder-flows --aie-lower-broadcast-packet --aie-create-packet-flows --aie-lower-multicast aie.mlir.prj/input_with_addresses.mlir -o aie.mlir.prj/input_physical.mlir
# Done in 0.022 sec: aie-opt --aie-create-pathfinder-flows --aie-lower-broadcast-packet --aie-create-packet-flows --aie-lower-multicast aie.mlir.prj/input_with_addresses.mlir -o aie.mlir.prj/input_physical.mlir
# aie-translate --aie-generate-xaie aie.mlir.prj/input_physical.mlir -o aie.mlir.prj/aie_inc.cpp
# make: Entering directory '/mnt/c/Users/advent/AppData/Local/Temp/pnxpn0863ic/build_template/aie.mlir.prj'
# /opt/tools/Vitis/2023.1/aietools/tps/lnx64/gcc/bin/g++ -fPIC -c -std=c++17 \
# -D__AIEARCH__=20 -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST \
# -Wno-deprecated-declarations -D__AIESIM__ -D__CDO__ -D__PS_INIT_AIE__ -D__AIE2IPU_BASE_ADDR_CDO__ -Og -flto \
# -I /opt/tools/Vitis/2023.1/aietools/include \
# -I /opt/tools/Vitis/2023.1/aietools/include/drivers/aiengine -I . \
#  -o generated-objects/gen_cdo.o generated-source/gen_cdo.cpp
# /opt/tools/Vitis/2023.1/aietools/tps/lnx64/gcc/bin/g++ -fPIC -c -std=c++17 -I . -I /opt/tools/Vitis/2023.1/aietools/include -o generated-objects/cdo_main.o generated-source/cdo_main.cpp
# /opt/tools/Vitis/2023.1/aietools/tps/lnx64/gcc/bin/g++ -o generated-objects/cdo_main.out generated-objects/gen_cdo.o generated-objects/cdo_main.o \
#  -Wl,--allow-shlib-undefined \
# -L /opt/tools/Vitis/2023.1/aietools/lib/lnx64.o -lcdo_driver -lxioutils -lxaiengine \
# -Wl,-R/opt/tools/Vitis/2023.1/aietools/tps/lnx64/gcc/lib64
# generated-objects/cdo_main.out --work-dir-path /mnt/c/Users/advent/AppData/Local/Temp/pnxpn0863ic/build_template/aie.mlir.prj/
# Generating: /mnt/c/Users/advent/AppData/Local/Temp/pnxpn0863ic/build_template/aie.mlir.prj/aie_cdo_error_handling.bin
# Generating: /mnt/c/Users/advent/AppData/Local/Temp/pnxpn0863ic/build_template/aie.mlir.prj/aie_cdo_elfs.bin
# Generating: /mnt/c/Users/advent/AppData/Local/Temp/pnxpn0863ic/build_template/aie.mlir.prj/aie_cdo_init.bin
# Generating: /mnt/c/Users/advent/AppData/Local/Temp/pnxpn0863ic/build_template/aie.mlir.prj/aie_cdo_enable.bin
# make: Leaving directory '/mnt/c/Users/advent/AppData/Local/Temp/pnxpn0863ic/build_template/aie.mlir.prj'
#
#
# ****** Bootgen v2023.1
#   **** Build date : Apr 18 2023-23:27:00
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2023 Advanced Micro Devices, Inc. All Rights Reserved.
#
#
# [INFO]   : Bootimage generated successfully
#
# XRT Build Version: 2.15.0 (Vitis)
#        Build Date: 2023-01-17 15:08:40
#           Hash ID: e9fc047c277d2d5b1991962729f4b5ed76110bb6
# Reading xclbin file into memory.  File: aie.mlir.prj/dev0.xclbin
#
# Section: 'AIE_PARTITION'(32) was successfully added.
# Size   : 5712 bytes
# Format : JSON
# File   : 'aie.mlir.prj/aie_partition.json'
#
# Section 'GROUP_TOPOLOGY'(26) was successfully removed
#
# Section 'GROUP_CONNECTIVITY'(27) was successfully removed
# Successfully wrote (39129 bytes) to the output file: final.xclbin
# Leaving xclbinutil.
# Done in 0.021 sec: aie-translate --aie-generate-xaie aie.mlir.prj/input_physical.mlir -o aie.mlir.prj/aie_inc.cpp
# aie-translate --aie-generate-cdo aie.mlir.prj/input_physical.mlir -o aie.mlir.prj/aie_control.cpp
# Done in 0.019 sec: aie-translate --aie-generate-cdo aie.mlir.prj/input_physical.mlir -o aie.mlir.prj/aie_control.cpp
# aie-translate aie.mlir.prj/input_with_addresses.mlir --aie-generate-bcf --tilecol=0 --tilerow=2 -o aie.mlir.prj/core_0_2.bcf
# Done in 0.020 sec: aie-translate aie.mlir.prj/input_with_addresses.mlir --aie-generate-bcf --tilecol=0 --tilerow=2 -o aie.mlir.prj/core_0_2.bcf
# awk /_include _file/ {print($3)} aie.mlir.prj/core_0_2.bcf
# xchesscc_wrapper aie2 +w aie.mlir.prj/work -d -f aie.mlir.prj/input.o mmul.o +l aie.mlir.prj/core_0_2.bcf -o ./core_0_2.elf
# Done in 5.728 sec: xchesscc_wrapper aie2 +w aie.mlir.prj/work -d -f aie.mlir.prj/input.o mmul.o +l aie.mlir.prj/core_0_2.bcf -o ./core_0_2.elf
# make -C aie.mlir.prj
# Done in 3.346 sec: make -C aie.mlir.prj
# aie.mlir.prj/kernels.json
# aie.mlir.prj/design.bif
# bootgen -arch versal -image aie.mlir.prj/design.bif -o aie.mlir.prj/design.pdi -w
# Done in 0.643 sec: bootgen -arch versal -image aie.mlir.prj/design.bif -o aie.mlir.prj/design.pdi -w
# xclbinutil --input aie.mlir.prj/dev0.xclbin --add-kernel aie.mlir.prj/kernels.json --add-section AIE_PARTITION:JSON:aie.mlir.prj/aie_partition.json --force --output final.xclbin
# Done in 0.705 sec: xclbinutil --input aie.mlir.prj/dev0.xclbin --add-kernel aie.mlir.prj/kernels.json --add-section AIE_PARTITION:JSON:aie.mlir.prj/aie_partition.json --force --output final.xclbin
#  AIE Compilation: ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:05 2/2 4 Workers
#
# compiling aie.mlir
#
#
# Successfully Building Application... Mmul.xclbin & Mmul.seq delivered

# %%
app_builder.metadata
# Out:
# {'application': 'Mmul',
#  'kernels': OrderedDict([('itbuffer_0',
#                {'name': 'itbuffer_0',
#                 'tloc': None,
#                 'ttype': 'IT',
#                 'ktype': 'buffer',
#                 'type': 'IT',
#                 'ports': {'ITin': {'c_dtype': None,
#                   'direction': 'in',
#                   'name': 'ITin',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'},
#                  'ITout': {'c_dtype': None,
#                   'direction': 'out',
#                   'name': 'ITout',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'}},
#                 'shape': (64, 64),
#                 'dtype': 'uint8'}),
#               ('itbuffer_1',
#                {'name': 'itbuffer_1',
#                 'tloc': None,
#                 'ttype': 'IT',
#                 'ktype': 'buffer',
#                 'type': 'IT',
#                 'ports': {'ITin': {'c_dtype': None,
#                   'direction': 'in',
#                   'name': 'ITin',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'},
#                  'ITout': {'c_dtype': None,
#                   'direction': 'out',
#                   'name': 'ITout',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'}},
#                 'shape': (64, 64),
#                 'dtype': 'uint8'}),
#               ('itbuffer_2',
#                {'name': 'itbuffer_2',
#                 'tloc': None,
#                 'ttype': 'IT',
#                 'ktype': 'buffer',
#                 'type': 'IT',
#                 'ports': {'ITin': {'c_dtype': None,
#                   'direction': 'in',
#                   'name': 'ITin',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'},
#                  'ITout': {'c_dtype': None,
#                   'direction': 'out',
#                   'name': 'ITout',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'}},
#                 'shape': (64, 64),
#                 'dtype': 'uint8'}),
#               ('mmul_0',
#                {'name': 'mmul_0',
#                 'tloc': (0, 2),
#                 'ttype': 'CT',
#                 'ktype': 'mmul',
#                 'type': 'CT',
#                 'ports': {'pA': {'c_dtype': None,
#                   'direction': 'in',
#                   'name': 'pA',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'},
#                  'pB': {'c_dtype': None,
#                   'direction': 'in',
#                   'name': 'pB',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'},
#                  'pC': {'c_dtype': None,
#                   'direction': 'out',
#                   'name': 'pC',
#                   'ctype': None,
#                   'shape': (64, 64),
#                   'dtype': 'uint8'}}})]),
#  'connections': OrderedDict([('itbuffer_0___ITout___mmul_0___pA',
#                {'name': 'itbuffer_0___ITout___mmul_0___pA',
#                 'srckernel': 'itbuffer_0',
#                 'srcport': 'ITout',
#                 'sinkkernel': 'mmul_0',
#                 'sinkport': 'pA',
#                 'dtype': 'uint8 *',
#                 'ctype': None}),
#               ('itbuffer_1___ITout___mmul_0___pB',
#                {'name': 'itbuffer_1___ITout___mmul_0___pB',
#                 'srckernel': 'itbuffer_1',
#                 'srcport': 'ITout',
#                 'sinkkernel': 'mmul_0',
#                 'sinkport': 'pB',
#                 'dtype': 'uint8 *',
#                 'ctype': None}),
#               ('mmul_0___pC___itbuffer_2___ITin',
#                {'name': 'mmul_0___pC___itbuffer_2___ITin',
#                 'srckernel': 'mmul_0',
#                 'srcport': 'pC',
#                 'sinkkernel': 'itbuffer_2',
#                 'sinkport': 'ITin',
#                 'dtype': 'uint8_t * __restrict',
#                 'ctype': None})]),
#  'sequence': [{'name': 'itbuffer_0___ITout___mmul_0___pA',
#    'seqtype': 'buffer',
#    'offset': 0,
#    'nbytes': 4096,
#    'srckernelname': 'itbuffer_0',
#    'srcportname': 'ITout',
#    'srcdtype': 'uint8 *',
#    'srcslices': [],
#    'srcoffset': 0,
#    'srcnbytes': 4096,
#    'srcshape': (64, 64),
#    'snkkernelname': 'mmul_0',
#    'snkportname': 'pA',
#    'snkdtype': 'uint8_t * __restrict',
#    'snkslices': [],
#    'snkoffset': 0,
#    'snknbytes': 4096,
#    'snkshape': (64, 64)},
#   {'name': 'itbuffer_1___ITout___mmul_0___pB',
#    'seqtype': 'buffer',
#    'offset': 0,
#    'nbytes': 4096,
#    'srckernelname': 'itbuffer_1',
#    'srcportname': 'ITout',
#    'srcdtype': 'uint8 *',
#    'srcslices': [],
#    'srcoffset': 0,
#    'srcnbytes': 4096,
#    'srcshape': (64, 64),
#    'snkkernelname': 'mmul_0',
#    'snkportname': 'pB',
#    'snkdtype': 'uint8_t * __restrict',
#    'snkslices': [],
#    'snkoffset': 0,
#    'snknbytes': 4096,
#    'snkshape': (64, 64)},
#   {'name': 'mmul_0___pC___itbuffer_2___ITin',
#    'seqtype': 'buffer',
#    'offset': 0,
#    'nbytes': 4096,
#    'srckernelname': 'mmul_0',
#    'srcportname': 'pC',
#    'srcdtype': 'uint8_t * __restrict',
#    'srcslices': [],
#    'srcoffset': 0,
#    'srcnbytes': 4096,
#    'srcshape': (64, 64),
#    'snkkernelname': 'itbuffer_2',
#    'snkportname': 'ITin',
#    'snkdtype': 'uint8 *',
#    'snkslices': [],
#    'snkoffset': 0,
#    'snknbytes': 4096,
#    'snkshape': (64, 64)}]}

# %% [markdown]
# ## Application Code

# %%
import numpy as np
import time

import matplotlib.pyplot as plt
from npu.runtime import AppRunner


def partition_matrix(matrix, tile_size):
    rows, cols = matrix.shape
    tile_rows, tile_cols = tile_size
    tiled_matrix = (matrix.reshape(rows // tile_rows, tile_rows, cols // tile_cols, tile_cols).
            swapaxes(1, 2))
    # Flatten the tiled matrix back to the original shape
    return tiled_matrix.reshape(rows, cols)
    

app = AppRunner('Mmul.xclbin')

# AIE mmul API configuration. 
# The kernel will expect the left matrix to be tiled in (M,K) format
# The kernel will expect the right matrix to be tiled in (K,N) format
# The kernel will output a matrix tiled in (M,N) format
M = 8;
K = 8;
N = 8;

# Allocate app input and output buffers to exchange data with NPU
input_a = app.allocate(shape=(64,64), dtype=np.uint8)
input_b = app.allocate(shape=(64,64), dtype=np.uint8)
output_c = app.allocate(shape=(64,64), dtype=np.uint8)

# Load array into input buffer
dim = 1024
scaling_factors = np.arange(0, dim)  # Diagonal elements from 0 to dim-1
# Threshold the scaling factor since the arrays are uint8
threshold = 2**8-1
a = np.diag(scaling_factors)
a = np.where(a > threshold, 255, a)
b = np.ones(shape=(dim,dim), dtype=np.uint8)
c = np.zeros(shape=(dim,dim), dtype=np.uint8)
total_time = time.time()-time.time()
num_runs = 1
for _ in range(0, num_runs):
    c = np.zeros(shape=(dim,dim), dtype=np.uint8) # Reset output matrix c to zeros
    for row_a in range(0, a.shape[0], 64):
        for col_b in range(0, b.shape[1], 64):
            for col_a in range(0, a.shape[1], 64):
                a_tiled = partition_matrix(a[row_a:row_a+64,col_a:col_a+64], (M,K))
                b_tiled = partition_matrix(b[col_a:col_a+64,col_b:col_b+64], (K,N))
                input_a[:] = a_tiled
                input_b[:] = b_tiled
                # Pass input_image buffer to NPU
                input_a.sync_to_npu()
                input_b.sync_to_npu()
    
                # Run app on NPU
                start = time.time()
                app.call(input_a, input_b, output_c)
                total_time = total_time + (time.time() - start)
    
                # Get results from NPU via output_image buffer
                output_c.sync_from_npu()
                c[row_a:row_a+64,col_b:col_b+64] = c[row_a:row_a+64,col_b:col_b+64] + np.array(output_c)
total_time = total_time / num_runs

# Create a figure with two subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)

# Otain the CPU calculation time. Don't store in an object here
# because the calculation time will go to 0 after the first
# calculation if stored in an object.
start = time.time()
for _ in range(0, num_runs):
    a@b
total_cpu_time = (time.time() - start) / num_runs
expected_output = partition_matrix(a@b, (M,N))

# Display the images. Tile the axb since the output from
# the kernel will be tiled.
ax1.imshow(expected_output, cmap='gray')
ax1.set_title('Expected Output')

ax2.imshow(c, cmap='gray')
ax2.set_title('Output from Kernel')

ax3.imshow(c-expected_output, cmap='gray')
ax3.set_title('Actual-Expected')

# Show the plot
plt.show()

print('Application performance:')
print(f'Checking for error in kernel calculation: Min(Actual-Expected)={np.min(c-expected_output)}, Max(Actual-Expected)={np.max(c-expected_output)}')
print(f'total kernel calculation time (without tiling overhead)={total_time}')
print(f'total cpu calculation time={total_cpu_time}')
# Out:
# Application performance:
# Checking for error in kernel calculation: Min(Actual-Expected)=0, Max(Actual-Expected)=0
# total kernel calculation time (without tiling overhead)=1.394646406173706
# total cpu calculation time=5.595941543579102

# %% [markdown]
# Delete the buffers and application, otherwise the application will remain loaded onto the NPU device.

# %%
del app
